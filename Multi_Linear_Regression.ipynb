# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
dfcar = pd.read_csv(r"C:\Users\DELL\Downloads\CAR DETAILS FROM CAR DEKHO.csv")

# %%
dfcar
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
dfcar.shape
# Out:
# (4340, 8)

# %%
dfcar.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
dfcar["fuel"]
# Out:
# 0       Petrol
# 1       Petrol
# 2       Diesel
# 3       Petrol
# 4       Diesel
#          ...
# 4335    Diesel
# 4336    Diesel
# 4337    Petrol
# 4338    Diesel
# 4339    Petrol
# Name: fuel, Length: 4340, dtype: object

# %%
dfcar["fuel"].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
dfcar["fuel"].value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %%
dfcar["seller_type"].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
dfcar["seller_type"].value_counts()
# Out:
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64

# %%
dfcar.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
dfcar["transmission"].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
dfcar["owner"].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Fourth & Above Owner',
#        'Third Owner', 'Test Drive Car'], dtype=object)

# %%
dfcar["owner"].value_counts()
# Out:
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %%
dfcar["name"]
# Out:
# 0                             Maruti 800 AC
# 1                  Maruti Wagon R LXI Minor
# 2                      Hyundai Verna 1.6 SX
# 3                    Datsun RediGO T Option
# 4                     Honda Amaze VX i-DTEC
#                        ...
# 4335    Hyundai i20 Magna 1.4 CRDi (Diesel)
# 4336             Hyundai i20 Magna 1.4 CRDi
# 4337                    Maruti 800 AC BSIII
# 4338       Hyundai Creta 1.6 CRDi SX Option
# 4339                       Renault KWID RXT
# Name: name, Length: 4340, dtype: object

# %%
dfcar["name"].unique()
# Out:
# array(['Maruti 800 AC', 'Maruti Wagon R LXI Minor',
#        'Hyundai Verna 1.6 SX', ..., 'Mahindra Verito 1.5 D6 BSIII',
#        'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV',
#        'Hyundai i20 Magna 1.4 CRDi'], dtype=object)

# %%
dfcar["name"].nunique()
# Out:
# 1491

# %%
dfcar.drop("name", axis = 1)
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2007          60000      70000  Petrol  Individual       Manual
# 1     2007         135000      50000  Petrol  Individual       Manual
# 2     2012         600000     100000  Diesel  Individual       Manual
# 3     2017         250000      46000  Petrol  Individual       Manual
# 4     2014         450000     141000  Diesel  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 4335  2014         409999      80000  Diesel  Individual       Manual
# 4336  2014         409999      80000  Diesel  Individual       Manual
# 4337  2009         110000      83000  Petrol  Individual       Manual
# 4338  2016         865000      90000  Diesel  Individual       Manual
# 4339  2016         225000      40000  Petrol  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...

# %%
dfcar.drop("name", axis = 1, inplace = True)

# %%
dfcar
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2007          60000      70000  Petrol  Individual       Manual
# 1     2007         135000      50000  Petrol  Individual       Manual
# 2     2012         600000     100000  Diesel  Individual       Manual
# 3     2017         250000      46000  Petrol  Individual       Manual
# 4     2014         450000     141000  Diesel  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 4335  2014         409999      80000  Diesel  Individual       Manual
# 4336  2014         409999      80000  Diesel  Individual       Manual
# 4337  2009         110000      83000  Petrol  Individual       Manual
# 4338  2016         865000      90000  Diesel  Individual       Manual
# 4339  2016         225000      40000  Petrol  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...

# %% [markdown]
# ### Checking NaN

# %%
dfcar.isna().sum()
# Out:
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %% [markdown]
# ### Error Detection

# %%
dfcar.dtypes
# Out:
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# dtype: object

# %%
sns.boxplot(dfcar)
# Out:
# <Axes: >

# %%
sns.boxplot(dfcar["year"])
# Out:
# <Axes: ylabel='year'>

# %%
sns.boxplot(dfcar["selling_price"])
# Out:
# <Axes: ylabel='selling_price'>

# %%
sns.boxplot(dfcar["km_driven"])
# Out:
# <Axes: ylabel='km_driven'>

# %% [markdown]
# ### Error detection & rectification

# %%
dfcar.columns
# Out:
# Index(['year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
cols = ['year', 'selling_price', 'km_driven']

# %%
import time

# %%
for c in cols:
    print(c)
    time.sleep(0.5)
# Out:
# year
# selling_price
# km_driven

# %%
for c in cols:
    print(dfcar[c])
    time.sleep(0.5)
# Out:
# 0       2007.0
# 1       2007.0
# 2       2012.0
# 3       2017.0
# 4       2014.0
#          ...
# 4335    2014.0
# 4336    2014.0
# 4337    2009.0
# 4338    2016.0
# 4339    2016.0
# Name: year, Length: 4340, dtype: float64
# 0        60000.0
# 1       135000.0
# 2       600000.0
# 3       250000.0
# 4       450000.0
#           ...
# 4335    409999.0
# 4336    409999.0
# 4337    110000.0
# 4338    865000.0
# 4339    225000.0
# Name: selling_price, Length: 4340, dtype: float64
# 0        70000.0
# 1        50000.0
# 2       100000.0
# 3        46000.0
# 4       141000.0
#           ...
# 4335     80000.0
# 4336     80000.0
# 4337     83000.0
# 4338     90000.0
# 4339     40000.0
# Name: km_driven, Length: 4340, dtype: float64

# %%
for c in cols:
   print(dfcar[c].skew())
time.sleep(0.5)
# Out:
# -0.5563798621836554
# 0.9738455386463598
# 0.6828359669796925

# %%
for c in cols:
    q1 = dfcar[c].quantile(0.25)
    q3 = dfcar[c].quantile(0.75)
    iqr = q3-q1
    lower = q1 -(1.5 * iqr)
    upper = q3 +(1.5 * iqr)
    dfcar[c] = dfcar[c].map(lambda x : lower if x < lower else upper if x > upper else x)

# %%
sns.boxplot(dfcar)
# Out:
# <Axes: >

# %%
dfcar["fuel"].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
dfcar["seller_type"].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
dfcar["transmission"].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
dfcar["owner"].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Fourth & Above Owner',
#        'Third Owner', 'Test Drive Car'], dtype=object)

# %%
dfcar
# Out:
#         year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2007.0        60000.0    70000.0  Petrol  Individual       Manual
# 1     2007.0       135000.0    50000.0  Petrol  Individual       Manual
# 2     2012.0       600000.0   100000.0  Diesel  Individual       Manual
# 3     2017.0       250000.0    46000.0  Petrol  Individual       Manual
# 4     2014.0       450000.0   141000.0  Diesel  Individual       Manual
# ...      ...            ...        ...     ...         ...          ...
# 4335  2014.0       409999.0    80000.0  Diesel  Individual       Manual
# 4336  2014.0       409999.0    80000.0  Diesel  Individual       Manual
# 4337  2009.0       110000.0    83000.0  Petrol  Individual       Manual
# 4338  2016.0       865000.0    90000.0  Diesel  Individual       Manual
# 4339  2016.0       225000.0    40000.0  Petrol  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# ...

# %%
pd.get_dummies(dfcar, drop_first = True )
# Out:
#         year  selling_price  km_driven  fuel_Diesel  fuel_Electric  fuel_LPG  \
# 0     2007.0        60000.0    70000.0        False          False     False
# 1     2007.0       135000.0    50000.0        False          False     False
# 2     2012.0       600000.0   100000.0         True          False     False
# 3     2017.0       250000.0    46000.0        False          False     False
# 4     2014.0       450000.0   141000.0         True          False     False
# ...      ...            ...        ...          ...            ...       ...
# 4335  2014.0       409999.0    80000.0         True          False     False
# 4336  2014.0       409999.0    80000.0         True          False     False
# 4337  2009.0       110000.0    83000.0        False          False     False
# 4338  2016.0       865000.0    90000.0         True          False     False
# 4339  2016.0       225000.0    40000.0        False          False     False
#
# ...

# %% [markdown]
# ### Encoding using get dummies instead of one hot encoder

# %%
dfcar = pd.get_dummies(dfcar, drop_first = True )

# %%
dfcar
# Out:
#         year  selling_price  km_driven  fuel_Diesel  fuel_Electric  fuel_LPG  \
# 0     2007.0        60000.0    70000.0        False          False     False
# 1     2007.0       135000.0    50000.0        False          False     False
# 2     2012.0       600000.0   100000.0         True          False     False
# 3     2017.0       250000.0    46000.0        False          False     False
# 4     2014.0       450000.0   141000.0         True          False     False
# ...      ...            ...        ...          ...            ...       ...
# 4335  2014.0       409999.0    80000.0         True          False     False
# 4336  2014.0       409999.0    80000.0         True          False     False
# 4337  2009.0       110000.0    83000.0        False          False     False
# 4338  2016.0       865000.0    90000.0         True          False     False
# 4339  2016.0       225000.0    40000.0        False          False     False
#
# ...

# %%
dfcar.replace([False, True], [0,1])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6532\3363462876.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfcar.replace([False, True], [0,1])
#         year  selling_price  km_driven  fuel_Diesel  fuel_Electric  fuel_LPG  \
# 0     2007.0        60000.0    70000.0            0              0         0
# 1     2007.0       135000.0    50000.0            0              0         0
# 2     2012.0       600000.0   100000.0            1              0         0
# 3     2017.0       250000.0    46000.0            0              0         0
# 4     2014.0       450000.0   141000.0            1              0         0
# ...      ...            ...        ...          ...            ...       ...
# ...

# %%
dfcar.replace([False, True], [0,1], inplace = True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6532\884402071.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfcar.replace([False, True], [0,1], inplace = True)

# %%
dfcar
# Out:
#         year  selling_price  km_driven  fuel_Diesel  fuel_Electric  fuel_LPG  \
# 0     2007.0        60000.0    70000.0            0              0         0
# 1     2007.0       135000.0    50000.0            0              0         0
# 2     2012.0       600000.0   100000.0            1              0         0
# 3     2017.0       250000.0    46000.0            0              0         0
# 4     2014.0       450000.0   141000.0            1              0         0
# ...      ...            ...        ...          ...            ...       ...
# 4335  2014.0       409999.0    80000.0            1              0         0
# 4336  2014.0       409999.0    80000.0            1              0         0
# 4337  2009.0       110000.0    83000.0            0              0         0
# 4338  2016.0       865000.0    90000.0            1              0         0
# 4339  2016.0       225000.0    40000.0            0              0         0
#
# ...

# %% [markdown]
# ### Data Seperation

# %%
x = dfcar.drop("selling_price", axis = 1)

# %%
x
# Out:
#         year  km_driven  fuel_Diesel  fuel_Electric  fuel_LPG  fuel_Petrol  \
# 0     2007.0    70000.0            0              0         0            1
# 1     2007.0    50000.0            0              0         0            1
# 2     2012.0   100000.0            1              0         0            0
# 3     2017.0    46000.0            0              0         0            1
# 4     2014.0   141000.0            1              0         0            0
# ...      ...        ...          ...            ...       ...          ...
# 4335  2014.0    80000.0            1              0         0            0
# 4336  2014.0    80000.0            1              0         0            0
# 4337  2009.0    83000.0            0              0         0            1
# 4338  2016.0    90000.0            1              0         0            0
# 4339  2016.0    40000.0            0              0         0            1
#
#       seller_type_Individual  seller_type_Trustmark Dealer  \
# ...

# %%
y = dfcar["selling_price"]

# %%
y
# Out:
# 0        60000.0
# 1       135000.0
# 2       600000.0
# 3       250000.0
# 4       450000.0
#           ...
# 4335    409999.0
# 4336    409999.0
# 4337    110000.0
# 4338    865000.0
# 4339    225000.0
# Name: selling_price, Length: 4340, dtype: float64

# %% [markdown]
# ### Splitting

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train, y_test = train_test_split(x,y,test_size = 0.20, random_state = 42)

# %%
x.shape
# Out:
# (4340, 13)

# %%
x_train.shape
# Out:
# (3472, 13)

# %%
x_test.shape
# Out:
# (868, 13)

# %% [markdown]
# ### Create a Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lrmodel = LinearRegression()

# %%
lrmodel
# Out:
# LinearRegression()

# %%
lrmodel.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lrmodel.score(x_test, y_test)
# Out:
# 0.601128852428865

# %%
scorelist = []
for i in range(500):
    xtrain, xtest,ytrain, ytest = train_test_split(x,y,test_size = 0.20, random_state = i)
    lreg = LinearRegression()
    lreg.fit(xtrain, ytrain)
    sc = lreg.score(xtest, ytest)
    scorelist.append(sc)

m = max(scorelist)
print(m)
print(scorelist.index(m))
# Out:
# 0.6531545005909569
# 252
